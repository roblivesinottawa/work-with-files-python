# %%
# %pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 77 kB 97 kB/s
# Using legacy 'setup.py install' for PyPDF2, since package 'wheel' is not installed.
# ...
#     Running setup.py install for PyPDF2 ... done
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PyPDF2

# %%
def read_pdf():
	with open('recipe-book.pdf', 'r+b') as f:
		reader = PyPDF2.PdfFileReader(f)
		# print(reader.numPages)
		# print(reader.getDocumentInfo())

		for page in range(0, reader.numPages):
			pageObj = reader.getPage(page)
			print("\n" + pageObj.extractText())

# %%
if __name__ == '__main__':
    read_pdf()
# Out:
#
#
#
#
#
# 2
#
# Table of Contents
#
# COOKING WITH ASPARAG
# US
#
# 3
#
# A
# SPARAGUS AND
# A
# PPLE
# M
# IXED
# G
# REENS
#
#
# 3
#
# COOKING WITH BROCCOL
# I
#
# 5
#
# R
# OASTED
# B
# ROCCOLI WITH
# G
# ARLIC AND
# R
# ED
# P
# EPPER
#
#
# 5
#
# COOKING WITH BUTTERN
# UT SQUASH
#
# 7
#
# F
# ARMHOUSE
# B
# UTTERNUT
# S
# QUASH
# S
# OUP
#
#
# 7
#
# COOKING WITH CABBAGE
#
# 9
#
# L
# ADY
#
# S
# C
# ABBAGE
#
#
# 9
#
# COOKING WITH CARROTS
#
# 11
#
# C
# IDER
# -
# G
# LAZED
# S
# PICED
# C
# ARROTS
#
#
# 11
#
# COOKING WITH EGGPLAN
# T
#
# 13
#
# M
# ARINATED
# E
# GGPLANT
#
#
# 13
#
# COOKING WITH SPINACH
#
# 15
#
# V
# EGAN
# N
# ORWEGIAN
# S
# PINACH
# S
# OUP
#
#
# 15
#
#
#
#
#
# Cooking with Asparagus
#
#
# Asparagus is a low
# -
# calorie source of folate and potassium, and its stalks are high in
# antioxidants.  Asparagus is high
# in roughly half the recommended
#
# daily intake of
# folate,
# a key nutrient in taming homocysteine, a substance implicated in heart
# ...

# %%
import pandas as pd

# %%
# %pip install tabula-py
# Out:
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/25/aa/40404ffebbd1bb4d19ae4445f1eb63be8e12c5ab0146d0bf7e78c8d09e2e/tabula_py-2.3.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/25/aa/40404ffebbd1bb4d19ae4445f1eb63be8e12c5ab0146d0bf7e78c8d09e2e/tabula_py-2.3.0-py3-none-any.whl
# ...

# %%
import tabula

# %%
df = tabula.read_pdf('recipe-book.pdf', pages='all')
# Out:
# Error from tabula-java:
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /var/folders/b3/ps0s4g_96g765d102cx6xf6r0000gn/T/ipykernel_22805/926223335.py in <module>
# ----> 1 df = tabula.read_pdf('recipe-book.pdf', pages='all')
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tabula/io.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
#     320
#     321     try:
# --> 322         output = _run(java_options, kwargs, path, encoding)
#     323     finally:
#     324         if temporary:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tabula/io.py in _run(java_options, options, path, encoding)
#      78
# ...

# %%
tabula.convert_into('recipe-book.pdf', 'recipe-book.csv', output_format='csv', pages='all')

# %%
df.head()
